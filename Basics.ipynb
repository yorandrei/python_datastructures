# %% [markdown]
# ## Namespaces Example

# %%
a = 20; b = 30
def my_func():
    global a
    a = 21; b = 31
    
my_func()
print(a) # prints 21
print(b) # prints 30
# Out:
# 21
# 30

# %%
x = 0
while x < 3: print(x); x += 1
# Out:
# 0
# 1
# 2

# %%
'persepholis'.count('e', 1, 4)
# Out:
# 1

# %%
'12ljkew'.isalnum()
# Out:
# True

# %%
'prehistoriprelinx'.replace('pre', 'post', 1)
# Out:
# 'posthistoriprelinx'

# %%
greet = 'hello world'
print(greet.split(' ')[1])
# Out:
# world

# %%
print(greet[::-1])
# Out:
# dlrow olleh

# %%
print(greet[:5] + ' wonderful' + greet[5:])
# Out:
# hello wonderful world

# %%
l = list(greet)
print(l)
# Out:
# ['h', 'e', 'l', 'l', 'o', ' ', 'w', 'o', 'r', 'l', 'd']

# %%
l = list(greet)
l.reverse(); l.append('f'); l.reverse()
print(l)
# Out:
# ['f', 'h', 'e', 'l', 'l', 'o', ' ', 'w', 'o', 'r', 'l', 'd']

# %%
x = 1; y = 2; z = 3
list1 = [x, y, z]
list2 = list1
list2[1] = 4
print(list1)
# Out:
# [1, 4, 3]

# %%
print(y)
# Out:
# 2

# %%
l = [2, 4, 8, 16]
print([i**3 for i in l])
# Out:
# [8, 64, 512, 4096]

# %%
def f1(x): return x*2
def f2(x): return x*4
lst = []
for i in range(16):
    lst.append(f1(f2(i)))
print(lst)
# Out:
# [0, 8, 16, 24, 32, 40, 48, 56, 64, 72, 80, 88, 96, 104, 112, 120]

# %%
def f1(x): return x*2
def f2(x): return x*4
#print([f1(x) for x in range(64)])
print([f1(x) for x in range(64) if x in [f2(j) for j in range(16)]])
# Out:
# [0, 8, 16, 24, 32, 40, 48, 56, 64, 72, 80, 88, 96, 104, 112, 120]

# %%
lst1 = [[1, 2, 3],[4, 5, 6]]
print([i*j for i in lst1[0] for j in lst1[1]])
# Out:
# [4, 5, 6, 8, 10, 12, 12, 15, 18]

# %%
words = 'here is a sentence'.split()
print([[word, len(word)] for word in words])
# Out:
# [['here', 4], ['is', 2], ['a', 1], ['sentence', 8]]

# %% [markdown]
# ## First-Class Objects - Functions

# %%
def greeting(language):
    if language == 'eng':
        return 'hello world'
    if language == 'fr':
        return 'Bonjour le monde'
    else: 
        return 'language not supported'
    
l = [greeting('eng'), greeting('fr'), greeting('ger')]
print(l[1])
# Out:
# Bonjour le monde

# %%
def callf(f):
    lang = 'eng'
    return (f(lang))

print(callf(greeting))
# Out:
# hello world

# %%
lst = [1, 2, 3, 4]
print(list(map(lambda x: x**3, lst)))
# Out:
# [1, 8, 27, 64]

# %%
print([x**3 for x in lst])
# Out:
# [1, 8, 27, 64]

# %%
print(list(filter((lambda x: x<3), lst)))
# Out:
# [1, 2]

# %%
print([x for x in lst if x<3])
# Out:
# [1, 2]

# %%
words = str.split("The longest word in the sentence")
print(sorted(words, key=len))
# Out:
# ['in', 'The', 'the', 'word', 'longest', 'sentence']

# %%
sl = ['A', 'b', 'a', 'C', 'c']
sl.sort(key=str.lower)
print(sl)
# Out:
# ['A', 'a', 'b', 'C', 'c']

# %%
sl.sort()
print(sl)
# Out:
# ['A', 'C', 'a', 'b', 'c']

# %%
sl
# Out:
# ['A', 'C', 'a', 'b', 'c']

# %%
print(sorted("Perspecacion"))
# Out:
# ['P', 'a', 'c', 'c', 'e', 'e', 'i', 'n', 'o', 'p', 'r', 's']

# %%
items = [['rice', 2.4, 8], ['flower', 1.8, 5], ['corn', 4.7, 6]]
items
# Out:
# [['rice', 2.4, 8], ['flower', 1.8, 5], ['corn', 4.7, 6]]

# %%
# Sort by price
items.sort(key=lambda item: item[1])
print(items)
# Out:
# [['flower', 1.8, 5], ['rice', 2.4, 8], ['corn', 4.7, 6]]

# %% [markdown]
# ## Recursive Functions

# %%
def iterTest(low, high):
    while low <= high:
        print(low)
        low = low + 1
        
def recurTest(low, high):
    if low <= high:
        print(low)
        recurTest(low+1, high)
        
iterTest(0, 5)
# Out:
# 0
# 1
# 2
# 3
# 4
# 5

# %%
recurTest(0, 5)
# Out:
# 0
# 1
# 2
# 3
# 4
# 5

# %% [markdown]
# ## Generators

# %%
# the running time of the list is compared to the generator 
import time
# an iterator containing odd numbers between the letters n and m
# is created by the generator function
def oddGen(n, m):
    while n < m:
        yield n
        n += 2
        
# a list of odd numbers from n to m is build
def oddList(n, m):
    lst = []
    while n < m:
        lst.append(n)
        n += 2
    return lst

# the length of time taken for a sum to be performed on an iterator
t1 = time.time()
sum(oddGen(1,100_000_000))
print("Time to sum an iterator: %f" % (time.time() - t1))

# the length of time taken to build a list and sum it 
t1 = time.time()
sum(oddList(1,100_000_000))
print("Time to build and sim a list: %f" %(time.time() - t1))
# Out:
# Time to sum an iterator: 6.328081
# Time to build and sim a list: 9.835116

# %%
for i in oddGen(1, 10): print(i)
# Out:
# 1
# 3
# 5
# 7
# 9

# %%
lst1 = [1, 2, 3, 4]
gen1 = (10**i for i in lst1)
print(gen1)
# Out:
# <generator object <genexpr> at 0x000002182F99DA20>

# %%
for x in gen1: print(x)
# Out:
# 10
# 100
# 1000
# 10000

# %% [markdown]
# # OOP

# %%
class Employee(object):
    numEmployee = 0
    
    def __init__(self, name, rate):
        self.owed = 0
        self.name = name
        self.rate = rate
        Employee.numEmployee += 1
        
    def __del__(self):
        Employee.numEmployee -= 1
        
    def hours(self, numHours):
        self.owed += numHours * self.rate
        return("%.2f hours worked" % numHours)
    
    def pay(self):
        self.owed = 0
        return("payed %s" % self.name)
    
emp1 = Employee("Jill", 15.50)
emp2 = Employee("Jack", 15.50)
print(Employee.numEmployee)
# Out:
# 2

# %%
print(emp1.hours(20))
# Out:
# 20.00 hours worked

# %%
print(emp1.owed)
# Out:
# 310.0

# %%
print(emp1.pay())
# Out:
# payed Jill

# %% [markdown]
# ## Plots

# %%
import matplotlib.pyplot as plt
fig = plt.figure()
ax = fig.add_subplot(111)
ax.plot([1, 2, 3, 4], [10, 20, 25, 30], color='lightblue', linewidth=3)
ax.scatter([0.3, 3.8, 1.2, 2.5], [11, 25, 9, 26], color='darkgreen', marker='^')
ax.set_xlim(0.5, 4.5)
plt.show()

# %%
import matplotlib.pyplot as plt
plt.plot([1, 2, 3, 4], [10, 20, 25, 30], color='lightblue', linewidth=3)
plt.scatter([0.3, 3.8, 1.2, 2.5], [11, 25, 9, 26], color='darkgreen', marker='^')
plt.xlim(0.0, 4.5)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np


#time = frange(-4, 4, 0.1)
time = [-4, 4, 0.1]
signal = [x*0.3 for x in time]
plt.plot(time, signal)
plt.show()


def frange(start, stop, step):
    return [start, stop, step]

# %%
import matplotlib.pyplot as plt
import numpy as np

time = np.arange(-4., 4., 0.1, dtype=np.float)
signal = time * 0.3
plt.plot(time, signal)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

time = np.arange(-2*np.pi, 2*np.pi, 0.1)
signal = np.sin(time)
plt.plot(time, signal)

timeMark = [-np.pi, -np.pi*0.5, 0, np.pi*0.5, np.pi]
markers = np.sin(timeMark)
plt.scatter(timeMark, markers, color='darkred')
plt.show()

# %%
import numpy as np
from imageio import imread
import matplotlib.pyplot as plt

img = imread('imageio:chelsea.png')
img_tinted = img * [1, 0.95, 0.9]

plt.subplot(1, 2, 1)
plt.imshow(img)

plt.subplot(1, 2, 2)
plt.imshow(np.uint8(img_tinted))

plt.show()

# %%
import imageio as io
import matplotlib.pyplot as plt
from numpy import genfromtxt

data = genfromtxt('data/fpga_in_20.csv', 
                  delimiter=',', 
                  skip_header=550,
                  skip_footer=300,
                  dtype=np.int16)
minVal = data.min()
maxVal = data.max()
byte_array = np.round(255.0 * (data - minVal) 
                      / (maxVal - minVal - 1.0)).astype(np.uint8)
io.imsave('echos.png', byte_array)

img = io.imread('echos.png')
fig, ax = plt.subplots(figsize=(20, 90))
im = ax.imshow(img)#, cmap='gray')

plt.show()

# %%
import matplotlib.pyplot as plt

def example_plot(ax, fontsize=12):
    ax.plot([1, 2])
    ax.locator_params(nbins=3)
    ax.set_xlabel('x-label', fontsize=fontsize)
    ax.set_ylabel('y-label', fontsize=fontsize)
    ax.set_title('Title', fontsize=fontsize)

plt.close('all')
fig = plt.figure()

ax1 = plt.subplot(221)
ax2 = plt.subplot(223)
ax3 = plt.subplot(122)

example_plot(ax1)
example_plot(ax2)
example_plot(ax3)

plt.tight_layout()

# %%
plt.close('all')
fig = plt.figure()

ax1 = plt.subplot2grid((3, 3), (0, 0))
ax2 = plt.subplot2grid((3, 3), (0, 1), colspan=2)
ax3 = plt.subplot2grid((3, 3), (1, 0), colspan=2, rowspan=2)
ax4 = plt.subplot2grid((3, 3), (1, 2), rowspan=2)

example_plot(ax1)
example_plot(ax2)
example_plot(ax3)
example_plot(ax4)

plt.tight_layout()

# %%
import numpy as np
import matplotlib.pyplot as plt

arr = np.arange(100).reshape((10, 10))
plt.close('all')
fig = plt.figure(figsize=(10, 8))

ax = plt.subplot(111)
im = ax.imshow(arr, interpolation="none")

plt.colorbar(im, use_gridspec=True)

plt.tight_layout()

# %%
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.widgets import Slider, Button, RadioButtons

fig, ax = plt.subplots()
plt.subplots_adjust(left=0.25, bottom=0.25)
t = np.arange(0.0, 1.0, 0.001)
a0 = 5
f0 = 3
delta_f = 5.0
s = a0*np.sin(2*np.pi*f0*t)
l, = plt.plot(t, s, lw=2, color='red')
plt.axis([0, 1, -10, 10])

axcolor = 'lightgoldenrodyellow'
axfreq = plt.axes([0.25, 0.1, 0.65, 0.03], facecolor=axcolor)
axamp = plt.axes([0.25, 0.15, 0.65, 0.03], facecolor=axcolor)

sfreq = Slider(axfreq, 'Freq', 0.1, 30.0, valinit=f0, valstep=delta_f)
samp = Slider(axamp, 'Amp', 0.1, 10.0, valinit=a0)


def update(val):
    amp = samp.val
    freq = sfreq.val
    l.set_ydata(amp*np.sin(2*np.pi*freq*t))
    fig.canvas.draw_idle()
sfreq.on_changed(update)
samp.on_changed(update)

resetax = plt.axes([0.8, 0.025, 0.1, 0.04])
button = Button(resetax, 'Reset', color=axcolor, hovercolor='0.975')


def reset(event):
    sfreq.reset()
    samp.reset()
button.on_clicked(reset)

rax = plt.axes([0.025, 0.5, 0.15, 0.15], facecolor=axcolor)
radio = RadioButtons(rax, ('red', 'blue', 'green'), active=0)


def colorfunc(label):
    l.set_color(label)
    fig.canvas.draw_idle()
radio.on_clicked(colorfunc)

plt.show()

# %%
help(fig.canvas.draw_idle)
# Out:
# Help on method draw_idle in module matplotlib.backend_bases:
#
# draw_idle(*args, **kwargs) method of matplotlib.backends.backend_agg.FigureCanvasAgg instance
#     :meth:`draw` only if idle; defaults to draw but backends can override
